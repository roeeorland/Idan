# %%
import pandas as pd

# %%
df = pd.read_excel('ratings.xlsx')

# %%
df
# Out:
#                         Program Name Channel Name   Pgm Date      Day  \
# 0               ג'ק ריצ'ר (טום קרוז)      yes4 HD 2018-12-03   Monday
# 1                        הבלתי אפשרי      yes1 HD 2018-12-03   Monday
# 2                       עד קצה העולם      yes1 HD 2018-12-03   Monday
# 3                    בדיוק כשהתאהבנו      yes1 HD 2018-12-04  Tuesday
# 4                        מיסטיק פיצה      yes1 HD 2018-12-04  Tuesday
# 5                           בת הנשיא      yes2 HD 2018-12-04  Tuesday
# 6                        הבלתי אפשרי      yes1 HD 2018-12-04  Tuesday
# 7                 הכשרון של מר ריפלי      yes4 HD 2018-12-04  Tuesday
# 8                         צוות שנחאי      yes2 HD 2018-12-03   Monday
# 9                              RED 2      yes4 HD 2018-12-03   Monday
# 10                        איש נובמבר      yes4 HD 2018-12-04  Tuesday
# 11                אי אפשר לקנות אהבה      yes1 HD 2018-12-03   Monday
# ...

# %%
df[(df['Program Name'] == "הבלתי אפשרי")]
# Out:
#   Program Name Channel Name   Pgm Date      Day Start Time End Time      Live  \
# 1  הבלתי אפשרי      yes1 HD 2018-12-03   Monday      21:30    23:19  0.024562
# 6  הבלתי אפשרי      yes1 HD 2018-12-04  Tuesday      14:29    16:18  0.016741
#
#         PVR     Total
# 1  0.001974  0.026536
# 6  0.000482  0.017223

# %%
df[(df['Program Name'] == "הבלתי אפשרי") & (df['Day'] == 'Monday')]
# Out:
#   Program Name Channel Name   Pgm Date     Day Start Time End Time      Live  \
# 1  הבלתי אפשרי      yes1 HD 2018-12-03  Monday      21:30    23:19  0.024562
#
#         PVR     Total
# 1  0.001974  0.026536

# %%
totals = df[df['Program Name'] == "הבלתי אפשרי"]['Total'].sum()

# %%
print(f"sum of totals for this show is: {totals}")
# Out:
# sum of totals for this show is: 0.0437587018923624
